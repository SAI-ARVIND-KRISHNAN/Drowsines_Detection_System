# %% [markdown]
# # DEPENDENCIES

# %%
# !pip3 install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu116
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu116
# Requirement already satisfied: torch in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (1.12.1)
# Collecting torchvision
#   Downloading torchvision-0.16.0-cp310-cp310-macosx_10_13_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 4.0 MB/s eta 0:00:00a 0:00:010m
# Collecting torchaudio
#   Downloading torchaudio-2.1.0-cp310-cp310-macosx_10_13_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 6.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: typing_extensions in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from torch) (4.4.0)
# Collecting torch
#   Downloading torch-2.1.0-cp310-none-macosx_10_9_x86_64.whl (147.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.0/147.0 MB 5.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: requests in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: numpy in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from torchvision) (1.23.5)
# Requirement already satisfied: networkx in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from torch) (2.8.4)
# Requirement already satisfied: sympy in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from torch) (1.11.1)
# Requirement already satisfied: filelock in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from torch) (3.9.0)
# Requirement already satisfied: jinja2 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from torch) (2022.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from requests->torchvision) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from requests->torchvision) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages/mpmath-1.2.1-py3.10.egg (from sympy->torch) (1.2.1)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1
#     Uninstalling torch-1.12.1:
#       Successfully uninstalled torch-1.12.1
# Successfully installed torch-2.1.0 torchaudio-2.1.0 torchvision-0.16.0

# %%
# !cd yolov5 & pip install -r yolov5/requirements.txt
# Out:
# Collecting gitpython>=3.1.30
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 327.1 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: matplotlib>=3.2.2 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 6)) (3.7.0)
# Requirement already satisfied: numpy>=1.18.5 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 7)) (1.23.5)
# Requirement already satisfied: opencv-python>=4.1.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 8)) (4.8.1.78)
# Requirement already satisfied: Pillow>=7.1.2 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 9)) (9.4.0)
# Requirement already satisfied: psutil in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 10)) (5.9.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 11)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 12)) (2.28.1)
# Requirement already satisfied: scipy>=1.4.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 13)) (1.10.0)
# Collecting thop>=0.1.1
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch>=1.7.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 15)) (2.1.0)
# Requirement already satisfied: torchvision>=0.8.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 16)) (0.16.0)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 17)) (4.64.1)
# Requirement already satisfied: tensorboard>=2.4.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 21)) (2.10.0)
# Requirement already satisfied: pandas>=1.1.4 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 26)) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 27)) (0.12.2)
# Requirement already satisfied: setuptools>=65.5.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 41)) (65.6.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 1.4 MB/s eta 0:00:0000:01
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 6)) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 6)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 6)) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 6)) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r yolov5/requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (3.4)
# Requirement already satisfied: typing-extensions in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (4.4.0)
# Requirement already satisfied: fsspec in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (2022.11.0)
# Requirement already satisfied: jinja2 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (3.1.2)
# Requirement already satisfied: sympy in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (1.11.1)
# Requirement already satisfied: networkx in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (2.8.4)
# Requirement already satisfied: filelock in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (3.9.0)
# Requirement already satisfied: wheel>=0.26 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 21)) (0.35.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 21)) (0.4.4)
# Requirement already satisfied: markdown>=2.6.8 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 21)) (3.4.1)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-py2.py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 2.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: grpcio>=1.24.3 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 21)) (1.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 21)) (2.6.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 21)) (1.6.0)
# Requirement already satisfied: absl-py>=0.4 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 21)) (1.3.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.4.1->-r yolov5/requirements.txt (line 21)) (2.2.2)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-macosx_10_9_x86_64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 2.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pytz>=2020.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from pandas>=1.1.4->-r yolov5/requirements.txt (line 26)) (2022.7)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 21)) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 21)) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 21)) (4.2.2)
# Requirement already satisfied: six>=1.9.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 21)) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 21)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 21)) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages/mpmath-1.2.1-py3.10.egg (from sympy->torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (1.2.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 21)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r yolov5/requirements.txt (line 21)) (3.2.2)
# Installing collected packages: tensorboard-data-server, smmap, protobuf, gitdb, thop, gitpython
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.0
#     Uninstalling tensorboard-data-server-0.7.0:
#       Successfully uninstalled tensorboard-data-server-0.7.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.23.1
#     Uninstalling protobuf-4.23.1:
#       Successfully uninstalled protobuf-4.23.1
# Successfully installed gitdb-4.0.11 gitpython-3.1.40 protobuf-3.20.3 smmap-5.0.1 tensorboard-data-server-0.6.1 thop-0.1.1.post2209072238

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# /Users/saiarvind/anaconda3/lib/python3.10/site-packages/torch/hub.py:294: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /Users/saiarvind/.cache/torch/hub/master.zip
# Collecting ultralytics
#   Downloading ultralytics-8.0.206-py3-none-any.whl (644 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from ultralytics) (3.7.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from ultralytics) (6.0)
# Requirement already satisfied: numpy>=1.22.2 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from ultralytics) (1.23.5)
# Requirement already satisfied: pandas>=1.1.4 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: torch>=1.8.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from ultralytics) (2.1.0)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from ultralytics) (4.64.1)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from ultralytics) (0.16.0)
# Collecting py-cpuinfo
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: thop>=0.1.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: scipy>=1.4.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from ultralytics) (1.10.0)
# Requirement already satisfied: pillow>=7.1.2 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: psutil in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from ultralytics) (4.8.1.78)
# Requirement already satisfied: requests>=2.23.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from ultralytics) (2.28.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (22.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2022.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: typing-extensions in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.4.0)
# Requirement already satisfied: sympy in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.11.1)
# Requirement already satisfied: networkx in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2.8.4)
# Requirement already satisfied: filelock in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.9.0)
# Requirement already satisfied: fsspec in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2022.11.0)
# Requirement already satisfied: jinja2 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: six>=1.5 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/saiarvind/anaconda3/lib/python3.10/site-packages/mpmath-1.2.1-py3.10.egg (from sympy->torch>=1.8.0->ultralytics) (1.2.1)
# Installing collected packages: py-cpuinfo, ultralytics
# Successfully installed py-cpuinfo-9.0.0 ultralytics-8.0.206
# requirements: Ultralytics requirement ['Pillow>=10.0.1'] not found, attempting AutoUpdate...
# Collecting Pillow>=10.0.1
#   Downloading Pillow-10.1.0-cp310-cp310-macosx_10_10_x86_64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 4.5 MB/s eta 0:00:00
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# Successfully installed Pillow-10.1.0
#
# requirements: AutoUpdate success ✅ 5.0s, installed 1 package: ['Pillow>=10.0.1']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 2023-11-5 Python-3.10.9 torch-2.1.0 CPU
#
# Fusing layers...
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
import os
import time

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# Collecting pyqt5
#   Downloading PyQt5-5.15.10-cp37-abi3-macosx_10_13_x86_64.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 5.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: lxml in /Users/saiarvind/anaconda3/lib/python3.10/site-packages (4.9.1)
# Collecting lxml
#   Downloading lxml-4.9.3.tar.gz (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 5.0 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting PyQt5-sip<13,>=12.13
#   Downloading PyQt5_sip-12.13.0-cp310-cp310-macosx_10_9_universal2.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.4/144.4 kB 7.2 MB/s eta 0:00:00
# Collecting PyQt5-Qt5>=5.15.2
#   Downloading PyQt5_Qt5-5.15.11-py3-none-macosx_10_13_x86_64.whl (40.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 4.7 MB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: lxml
#   Building wheel for lxml (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [125 lines of output]
#       Building lxml version 4.9.3.
#       Building without Cython.
#       Building against libxml2 2.9.14 and libxslt 1.1.35
#       Building against libxml2/libxslt in one of the following directories:
#         /Users/saiarvind/anaconda3/lib
#         /Users/saiarvind/anaconda3/lib
#         /Users/saiarvind/anaconda3/lib
#         /Users/saiarvind/anaconda3/lib
#         /Users/saiarvind/anaconda3/lib
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-10.9-x86_64-cpython-310
#       creating build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/_elementpath.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/sax.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/pyclasslookup.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/builder.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/doctestcompare.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/usedoctest.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/cssselect.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/ElementInclude.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       creating build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       creating build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/soupparser.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/defs.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/_setmixin.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/clean.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/_diffcommand.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/html5parser.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/formfill.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/builder.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/ElementSoup.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/_html5builder.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/usedoctest.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/diff.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       creating build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron
#       copying src/lxml/isoschematron/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron
#       copying src/lxml/etree.h -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/etree_api.h -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/lxml.etree.h -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/lxml.etree_api.h -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/objectify.pyx -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/etree.pyx -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/public-api.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/xmlid.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/cleanup.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/xslt.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/xpath.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/debug.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/serializer.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/classlookup.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/saxparser.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/objectpath.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/relaxng.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/xinclude.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/iterparse.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/parser.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/dtd.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/apihelpers.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/xmlerror.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/readonlytree.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/extensions.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/xmlschema.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/schematron.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/docloader.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/nsclasses.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/parsertarget.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/xsltext.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/proxy.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/includes/xmlerror.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/c14n.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/xmlschema.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/__init__.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/schematron.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/tree.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/uri.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/etreepublic.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/xpath.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/htmlparser.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/xslt.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/config.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/xmlparser.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/xinclude.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/dtdvalid.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/relaxng.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/lxml-version.h -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/etree_defs.h -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       creating build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources
#       creating build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/rng
#       copying src/lxml/isoschematron/resources/rng/iso-schematron.rng -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/rng
#       creating build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/xsl
#       copying src/lxml/isoschematron/resources/xsl/XSD2Schtrn.xsl -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/xsl
#       copying src/lxml/isoschematron/resources/xsl/RNG2Schtrn.xsl -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/xsl
#       creating build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_abstract_expand.xsl -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_dsdl_include.xsl -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_schematron_skeleton_for_xslt1.xsl -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_svrl_for_xslt1.xsl -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_schematron_message.xsl -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/readme.txt -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       running build_ext
#       building 'lxml.etree' extension
#       creating build/temp.macosx-10.9-x86_64-cpython-310
#       creating build/temp.macosx-10.9-x86_64-cpython-310/src
#       creating build/temp.macosx-10.9-x86_64-cpython-310/src/lxml
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/saiarvind/anaconda3/include -fPIC -O2 -isystem /Users/saiarvind/anaconda3/include -DCYTHON_CLINE_IN_TRACEBACK=0 -I/Users/saiarvind/anaconda3/include/libxml2 -I/Users/saiarvind/anaconda3/include -Isrc -Isrc/lxml/includes -I/Users/saiarvind/anaconda3/include/python3.10 -c src/lxml/etree.c -o build/temp.macosx-10.9-x86_64-cpython-310/src/lxml/etree.o -w -flat_namespace
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       Compile failed: command '/usr/bin/clang' failed with exit code 1
#       creating var
#       creating var/folders
#       creating var/folders/ht
#       creating var/folders/ht/3zlctr2x05593f7z8wrhy4fr0000gn
#       creating var/folders/ht/3zlctr2x05593f7z8wrhy4fr0000gn/T
#       cc -I/Users/saiarvind/anaconda3/include/libxml2 -I/Users/saiarvind/anaconda3/include -I/usr/include/libxml2 -c /var/folders/ht/3zlctr2x05593f7z8wrhy4fr0000gn/T/xmlXPathInitf7vxheu6.c -o var/folders/ht/3zlctr2x05593f7z8wrhy4fr0000gn/T/xmlXPathInitf7vxheu6.o
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       *********************************************************************************
#       Could not find function xmlCheckVersion in library libxml2. Is libxml2 installed?
#       Perhaps try: xcode-select --install
#       *********************************************************************************
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for lxml
#   Running setup.py clean for lxml
# Failed to build lxml
# Installing collected packages: PyQt5-Qt5, PyQt5-sip, lxml, pyqt5
#   Attempting uninstall: PyQt5-sip
#     Found existing installation: PyQt5-sip 12.11.0
#     Uninstalling PyQt5-sip-12.11.0:
#       WARNING: Cannot remove entries from nonexistent file /Users/saiarvind/anaconda3/lib/python3.10/site-packages/easy-install.pth
#       Successfully uninstalled PyQt5-sip-12.11.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.9.1
#     Uninstalling lxml-4.9.1:
#       Successfully uninstalled lxml-4.9.1
#   Running setup.py install for lxml ... error
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for lxml did not run successfully.
#   │ exit code: 1
#   ╰─> [122 lines of output]
#       Building lxml version 4.9.3.
#       Building without Cython.
#       Building against libxml2 2.9.14 and libxslt 1.1.35
#       Building against libxml2/libxslt in one of the following directories:
#         /Users/saiarvind/anaconda3/lib
#         /Users/saiarvind/anaconda3/lib
#         /Users/saiarvind/anaconda3/lib
#         /Users/saiarvind/anaconda3/lib
#         /Users/saiarvind/anaconda3/lib
#       running install
#       /Users/saiarvind/anaconda3/lib/python3.10/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-10.9-x86_64-cpython-310
#       creating build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/_elementpath.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/sax.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/pyclasslookup.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/builder.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/doctestcompare.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/usedoctest.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/cssselect.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/ElementInclude.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       creating build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       creating build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/soupparser.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/defs.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/_setmixin.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/clean.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/_diffcommand.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/html5parser.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/formfill.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/builder.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/ElementSoup.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/_html5builder.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/usedoctest.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       copying src/lxml/html/diff.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/html
#       creating build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron
#       copying src/lxml/isoschematron/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron
#       copying src/lxml/etree.h -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/etree_api.h -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/lxml.etree.h -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/lxml.etree_api.h -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/objectify.pyx -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/etree.pyx -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/public-api.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/xmlid.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/cleanup.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/xslt.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/xpath.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/debug.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/serializer.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/classlookup.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/saxparser.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/objectpath.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/relaxng.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/xinclude.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/iterparse.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/parser.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/dtd.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/apihelpers.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/xmlerror.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/readonlytree.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/extensions.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/xmlschema.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/schematron.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/docloader.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/nsclasses.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/parsertarget.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/xsltext.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/proxy.pxi -> build/lib.macosx-10.9-x86_64-cpython-310/lxml
#       copying src/lxml/includes/xmlerror.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/c14n.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/xmlschema.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/__init__.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/schematron.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/tree.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/uri.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/etreepublic.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/xpath.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/htmlparser.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/xslt.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/config.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/xmlparser.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/xinclude.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/dtdvalid.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/relaxng.pxd -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/lxml-version.h -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       copying src/lxml/includes/etree_defs.h -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/includes
#       creating build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources
#       creating build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/rng
#       copying src/lxml/isoschematron/resources/rng/iso-schematron.rng -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/rng
#       creating build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/xsl
#       copying src/lxml/isoschematron/resources/xsl/XSD2Schtrn.xsl -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/xsl
#       copying src/lxml/isoschematron/resources/xsl/RNG2Schtrn.xsl -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/xsl
#       creating build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_abstract_expand.xsl -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_dsdl_include.xsl -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_schematron_skeleton_for_xslt1.xsl -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_svrl_for_xslt1.xsl -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_schematron_message.xsl -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/readme.txt -> build/lib.macosx-10.9-x86_64-cpython-310/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#       running build_ext
#       building 'lxml.etree' extension
#       creating build/temp.macosx-10.9-x86_64-cpython-310
#       creating build/temp.macosx-10.9-x86_64-cpython-310/src
#       creating build/temp.macosx-10.9-x86_64-cpython-310/src/lxml
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/saiarvind/anaconda3/include -fPIC -O2 -isystem /Users/saiarvind/anaconda3/include -DCYTHON_CLINE_IN_TRACEBACK=0 -I/Users/saiarvind/anaconda3/include/libxml2 -I/Users/saiarvind/anaconda3/include -Isrc -Isrc/lxml/includes -I/Users/saiarvind/anaconda3/include/python3.10 -c src/lxml/etree.c -o build/temp.macosx-10.9-x86_64-cpython-310/src/lxml/etree.o -w -flat_namespace
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       Compile failed: command '/usr/bin/clang' failed with exit code 1
#       cc -I/Users/saiarvind/anaconda3/include/libxml2 -I/Users/saiarvind/anaconda3/include -I/usr/include/libxml2 -c /var/folders/ht/3zlctr2x05593f7z8wrhy4fr0000gn/T/xmlXPathInitk4t13917.c -o var/folders/ht/3zlctr2x05593f7z8wrhy4fr0000gn/T/xmlXPathInitk4t13917.o
#       xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#       *********************************************************************************
#       Could not find function xmlCheckVersion in library libxml2. Is libxml2 installed?
#       Perhaps try: xcode-select --install
#       *********************************************************************************
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Rolling back uninstall of lxml
#   Moving to /Users/saiarvind/anaconda3/lib/python3.10/site-packages/lxml-4.9.1.dist-info/
#    from /Users/saiarvind/anaconda3/lib/python3.10/site-packages/~xml-4.9.1.dist-info
#   Moving to /Users/saiarvind/anaconda3/lib/python3.10/site-packages/lxml/
#    from /Users/saiarvind/anaconda3/lib/python3.10/site-packages/~xml
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> lxml
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data data.yaml --weights yolov5s.pt --workers 2
# Out:
# /Users/saiarvind/anaconda3/lib/python3.10/site-packages/tensorflow/python/framework/dtypes.py:471: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/saiarvind/anaconda3/lib/python3.10/site-packages/tensorflow/python/framework/dtypes.py:472: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/saiarvind/anaconda3/lib/python3.10/site-packages/tensorflow/python/framework/dtypes.py:473: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/saiarvind/anaconda3/lib/python3.10/site-packages/tensorflow/python/framework/dtypes.py:474: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/saiarvind/anaconda3/lib/python3.10/site-packages/tensorflow/python/framework/dtypes.py:475: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# Traceback (most recent call last):
#   File "/Users/saiarvind/anaconda3/lib/python3.10/site-packages/tensorboard/compat/__init__.py", line 42, in tf
#     from tensorboard.compat import notf  # noqa: F401
# ImportError: cannot import name 'notf' from 'tensorboard.compat' (/Users/saiarvind/anaconda3/lib/python3.10/site-packages/tensorboard/compat/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/saiarvind/Desktop/TARP/yolov5/train.py", line 56, in <module>
#     from utils.loggers import Loggers
#   File "/Users/saiarvind/Desktop/TARP/yolov5/utils/loggers/__init__.py", line 12, in <module>
#     from torch.utils.tensorboard import SummaryWriter
#   File "/Users/saiarvind/anaconda3/lib/python3.10/site-packages/torch/utils/tensorboard/__init__.py", line 12, in <module>
#     from .writer import FileWriter, SummaryWriter  # noqa: F401
#   File "/Users/saiarvind/anaconda3/lib/python3.10/site-packages/torch/utils/tensorboard/writer.py", line 16, in <module>
#     from ._embedding import get_embedding_info, make_mat, make_sprite, make_tsv, write_pbtxt
#   File "/Users/saiarvind/anaconda3/lib/python3.10/site-packages/torch/utils/tensorboard/_embedding.py", line 9, in <module>
#     _HAS_GFILE_JOIN = hasattr(tf.io.gfile, "join")
#   File "/Users/saiarvind/anaconda3/lib/python3.10/site-packages/tensorboard/lazy.py", line 65, in __getattr__
#     return getattr(load_once(self), attr_name)
#   File "/Users/saiarvind/anaconda3/lib/python3.10/site-packages/tensorboard/lazy.py", line 97, in wrapper
#     cache[arg] = f(arg)
#   File "/Users/saiarvind/anaconda3/lib/python3.10/site-packages/tensorboard/lazy.py", line 50, in load_once
#     module = load_fn()
#   File "/Users/saiarvind/anaconda3/lib/python3.10/site-packages/tensorboard/compat/__init__.py", line 45, in tf
#     import tensorflow
#   File "/Users/saiarvind/anaconda3/lib/python3.10/site-packages/tensorflow/__init__.py", line 24, in <module>
#     from tensorflow.python import *
#   File "/Users/saiarvind/anaconda3/lib/python3.10/site-packages/tensorflow/python/__init__.py", line 93, in <module>
#     from tensorflow.python.ops.standard_ops import *
#   File "/Users/saiarvind/anaconda3/lib/python3.10/site-packages/tensorflow/python/ops/standard_ops.py", line 26, in <module>
#     from tensorflow.python.ops import array_grad
#   File "/Users/saiarvind/anaconda3/lib/python3.10/site-packages/tensorflow/python/ops/array_grad.py", line 30, in <module>
#     from tensorflow.python.ops import math_ops
#   File "/Users/saiarvind/anaconda3/lib/python3.10/site-packages/tensorflow/python/ops/math_ops.py", line 1145, in <module>
#     _OverrideBinaryOperatorHelper(gen_math_ops.logical_or, "or")
#   File "/Users/saiarvind/anaconda3/lib/python3.10/site-packages/tensorflow/python/ops/math_ops.py", line 910, in _OverrideBinaryOperatorHelper
#     clazz_object._override_operator("__%s__" % op_name, binary_op_wrapper)
#   File "/Users/saiarvind/anaconda3/lib/python3.10/site-packages/tensorflow/python/framework/ops.py", line 503, in _override_operator
#     _override_helper(Tensor, operator, func)
#   File "/Users/saiarvind/anaconda3/lib/python3.10/site-packages/tensorflow/python/framework/ops.py", line 66, in _override_helper
#     raise ValueError("operator %s cannot be overwritten again on class %s." %
# ValueError: operator __or__ cannot be overwritten again on class <class 'tensorflow.python.framework.ops.Tensor'>.

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp7/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /Users/saiarvind/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-11-5 Python-3.10.9 torch-2.1.0 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
# !pip install pygame
# Out:
# Collecting pygame
#   Downloading pygame-2.5.2-cp310-cp310-macosx_10_9_x86_64.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 6.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pygame
# Successfully installed pygame-2.5.2

# %%
import os
import random
import pygame

pygame.mixer.init()
folder_path = "music"

mp3_files = [file for file in os.listdir(folder_path) if file.endswith(".mp3")]
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.10.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
classes = [
'dog',
'person',
'cat',
'tv',
'car',
'meatballs',
'marinara sauce',
'tomato soup',
'chicken noodle soup',
'french onion soup',
'chicken breast',
'ribs',
'pulled pork',
'hamburger',
'cavity',
'awake',
'drowsy'
]

# %%
str(results).split('\n')[0].split(' ')[-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 str(results).split('\n')[0].split(' ')[-1]
#
# NameError: name 'results' is not defined

# %%
buffer = []

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    key = str(results).split('\n')[0].split(' ')[-1]
    
    if len(buffer) != 5:
        buffer.append(key)
    else:
        buffer = buffer[1:] + [key]
    
    if len(set(buffer)) == 1 and len(buffer) == 5 and buffer[0] == "drowsy":
        print("DROWSY")
        buffer = []
        '''
        mp3_file_path = os.path.join(folder_path, random_mp3_file)
        pygame.mixer.music.load(mp3_file_path)
        pygame.mixer.music.play()
        '''
        time.sleep(5)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        #pygame.mixer.music.stop()
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# DROWSY
# DROWSY
# DROWSY
# DROWSY
# DROWSY
# DROWSY
# DROWSY
# DROWSY
# DROWSY
# DROWSY
# DROWSY
# DROWSY
